# %% [markdown]
# #### Import required libraries
#
# By importing these libraries, you're setting up your Python environment to perform data analysis and visualization tasks efficiently

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the dataframe for EDA

# %%
df = pd.read_excel("D:\Data Science\EDA_Projects\Air Pollutants Dataset of Pune City, India\Air Pollutants Dataset of Pune City, India\Air_Pollution_Pune.xlsx")

df.head()
# Out:
#                  Date      Time  PM10 (ug/m3)  PM2.5 (ug/m3)  PM 1 (ug/m3)  \
# 0 2019-06-05 01:00:00  01:00:00         44.35          29.95         14.73
# 1 2019-06-05 02:00:00  02:00:00         42.13          28.35         13.93
# 2 2019-06-05 03:00:00  03:00:00         47.98          32.55         15.93
# 3 2019-06-05 04:00:00  04:00:00         58.43          39.73         19.33
# 4 2019-06-05 05:00:00  05:00:00         49.70          33.58         16.40
#
#    O3 (ppb)  CO (ppm)  NO (ppm)  NO2 (ppb)  Nox (ppb)  CO2 (ppm)
# 0       NaN       NaN       NaN        NaN        NaN        NaN
# 1       NaN       NaN       NaN        NaN        NaN        NaN
# 2       NaN       NaN       NaN        NaN        NaN        NaN
# 3       NaN       NaN       NaN        NaN        NaN        NaN
# 4       NaN       NaN       NaN        NaN        NaN        NaN

# %% [markdown]
# #### Check the shape of the data

# %%
df.shape
# Out:
# (26891, 11)

# %% [markdown]
# #### Columns Name

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'PM 1 (ug/m3)',
#        'O3 (ppb)', 'CO (ppm)', 'NO (ppm)', 'NO2 (ppb)', 'Nox (ppb)',
#        'CO2 (ppm)'],
#       dtype='object')

# %% [markdown]
# #### check the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26891 entries, 0 to 26890
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           26891 non-null  datetime64[ns]
#  1   Time           26891 non-null  object
#  2   PM10 (ug/m3)   26226 non-null  float64
#  3   PM2.5 (ug/m3)  26222 non-null  float64
#  4   PM 1 (ug/m3)   26225 non-null  float64
#  5   O3 (ppb)       21223 non-null  float64
#  6   CO (ppm)       21024 non-null  float64
#  7   NO (ppm)       21091 non-null  float64
#  8   NO2 (ppb)      21091 non-null  float64
#  9   Nox (ppb)      21090 non-null  float64
#  10  CO2 (ppm)      21022 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# #### Created the copy of dataframe

# %%
new_df = df[['Date', 'PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'PM 1 (ug/m3)',
       'O3 (ppb)', 'CO (ppm)', 'NO (ppm)', 'NO2 (ppb)', 'Nox (ppb)',
       'CO2 (ppm)']]

new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26891 entries, 0 to 26890
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           26891 non-null  datetime64[ns]
#  1   PM10 (ug/m3)   26226 non-null  float64
#  2   PM2.5 (ug/m3)  26222 non-null  float64
#  3   PM 1 (ug/m3)   26225 non-null  float64
#  4   O3 (ppb)       21223 non-null  float64
#  5   CO (ppm)       21024 non-null  float64
#  6   NO (ppm)       21091 non-null  float64
#  7   NO2 (ppb)      21091 non-null  float64
#  8   Nox (ppb)      21090 non-null  float64
#  9   CO2 (ppm)      21022 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 2.1 MB

# %% [markdown]
# #### Check the basic stats of dataset

# %%
new_df.describe()
# Out:
#        PM10 (ug/m3)  PM2.5 (ug/m3)  PM 1 (ug/m3)      O3 (ppb)      CO (ppm)  \
# count  26226.000000   26222.000000  26225.000000  21223.000000  21024.000000
# mean      64.890051      43.840304     24.649828     14.991083      2.498754
# std       48.486083      32.575912     19.266646     10.592137      4.779963
# min        2.150000       1.300000      0.100000      1.000000      0.010000
# 25%       24.500000      17.385000      8.930000      8.000000      0.710000
# 50%       52.730000      36.180000     20.200000     12.000000      0.900000
# 75%       96.800000      63.430000     36.230000     18.000000      1.050000
# max     1614.550000    1193.850000    668.530000     98.000000     32.820000
#
#            NO (ppm)     NO2 (ppb)     Nox (ppb)     CO2 (ppm)
# count  21091.000000  21091.000000  21090.000000  21022.000000
# mean       7.951034      8.213063     17.035411    412.144853
# std        7.309187      5.238268     13.144091     26.106888
# min        0.620000      0.500000      1.490000    151.400000
# 25%        3.590000      5.000000      9.260000    406.900000
# 50%        5.640000      7.690000     13.690000    414.200000
# 75%        9.060000     10.560000     19.717500    419.437500
# max       58.860000     46.900000    135.000000    695.200000

# %% [markdown]
# #### check the count of null values

# %%
new_df.isna().sum()
# Out:
# Date                0
# PM10 (ug/m3)      665
# PM2.5 (ug/m3)     669
# PM 1 (ug/m3)      666
# O3 (ppb)         5668
# CO (ppm)         5867
# NO (ppm)         5800
# NO2 (ppb)        5800
# Nox (ppb)        5801
# CO2 (ppm)        5869
# dtype: int64

# %% [markdown]
# As we see there are lot of columns contain null values but we decided to keep as it is, not to take action on this.

# %% [markdown]
# #### Distribution of pollutants using histograms

# %%
pollutants = ['PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'PM 1 (ug/m3)',
       'O3 (ppb)', 'CO (ppm)', 'NO (ppm)', 'NO2 (ppb)', 'Nox (ppb)',
       'CO2 (ppm)']
for pollutant in pollutants:
    plt.figure(figsize=(16, 12))
    sns.histplot(df[pollutant], bins=30, kde=True)
    plt.title(f'Distribution of {pollutant}')
    plt.xlabel(pollutant)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# As we seen for most of the pollutants having positive skewness except CO2. Also seems there is more variability in data. for better viz let check it through kernel density estimation (KDE) plot

# %%
plt.figure(figsize=(24, 16))
for i, col in enumerate(new_df.columns[1:]):
    plt.subplot(3, 3, i+1)
    sns.kdeplot(df[col], shade=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's check the time series plot of pollutants

# %%
plt.figure(figsize=(24, 12))
for col in df.columns[2:]:
    plt.plot(df['Date'], new_df[col], label=col)
plt.title('Time Series Plot of Pollutants')
plt.xlabel('Date')
plt.ylabel('Pollution Level')
plt.legend()
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# the pollutants intensity increases across the all these years

# %% [markdown]
# Let's check the outliers, comparing the pollutant with each other.

# %%
plt.figure(figsize=(24, 12))
sns.boxenplot(data=new_df.drop(columns=['Date']), color="skyblue")
plt.title('Boxen Plot of Pollutants')
plt.ylabel('Concentration')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# there are some outliers which might be the reason of positive skenwness

# %% [markdown]
# Relation between PM2.5 and PM10 as teheir source is one. both having similarity. Lets check through seasons and months.

# %%
sns.jointplot(x='PM2.5 (ug/m3)', y='PM10 (ug/m3)', data=new_df, kind='kde', cmap='viridis')
plt.title('KDE Joint Plot of PM2.5 vs PM10')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Extract hour and day of the week

# %%
new_df['Hour'] = new_df['Date'].dt.hour
new_df['DayOfWeek'] = new_df['Date'].dt.day_name()

# Group by hour and day of the week and calculate mean pollutant levels
hourly_mean = new_df.groupby('Hour').mean().reset_index()
dayofweek_mean = new_df.groupby('DayOfWeek').mean().reset_index()

# %% [markdown]
# #### Plot average pollutant levels by hour of the day

# %%
plt.figure(figsize=(24, 12))
for col in new_df.columns[1:-2]:  # Exclude non-pollutant columns
    plt.plot(hourly_mean['Hour'], hourly_mean[col], label=col)
plt.title('Average Pollutant Levels by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Average Concentration')
plt.legend()
plt.grid(True)
plt.xticks(np.arange(0, 24, step=1))
plt.tight_layout()
plt.show()

# %% [markdown]
# most peak we are able to see between 8 AM and 1 PM and then in the evening after 6PM. Look at CO2, as always on high.

# %% [markdown]
# #### Plot average pollutant levels by day of the week

# %%
plt.figure(figsize=(24,12))
for col in new_df.columns[1:-2]:  # Exclude non-pollutant columns
    plt.plot(dayofweek_mean['DayOfWeek'], dayofweek_mean[col], label=col)
plt.title('Average Pollutant Levels by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Concentration')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# not able to find such difference, everything looks flat across the weeks

# %% [markdown]
# #### Extract month and year

# %%
new_df['Month'] = new_df['Date'].dt.month
new_df['Year'] = new_df['Date'].dt.year

# %% [markdown]
# #### Group by month and year and calculate mean pollutant levels

# %%
monthly_mean = new_df.groupby(['Year', 'Month']).mean().reset_index()

# %% [markdown]
# #### Create a new 'Date' column from 'Year' and 'Month' for plotting

# %%
monthly_mean['Date'] = pd.to_datetime(monthly_mean[['Year', 'Month']].assign(day=1))

# %%
monthly_mean
# Out:
#     Year  Month  PM10 (ug/m3)  PM2.5 (ug/m3)  PM 1 (ug/m3)   O3 (ppb)  \
# 0   2019      6     43.851954      29.236013     14.485140        NaN
# 1   2019      7     29.705253      19.959003      9.505859        NaN
# 2   2019      8     27.222282      18.641562      9.041276        NaN
# 3   2019      9     26.807092      18.183531      8.744050        NaN
# 4   2019     10     52.012089      34.427647     16.881095        NaN
# 5   2019     11     83.589807      53.157081     24.939170        NaN
# 6   2019     12    106.660108      70.138048     34.150471  23.500000
# 7   2020      1     95.141429      62.619752     29.340175   7.768240
# 8   2020      2     93.704137      49.148653     21.273626  10.300469
# 9   2020      3     63.282681      42.444528     24.565403   9.459569
# 10  2020      4     56.084972      48.112875     28.129319  12.091667
# 11  2020      5     33.666617      24.393895     13.618989  14.575269
# 12  2020      6     23.348738      18.176592      8.346396  19.556962
# 13  2020      7     18.990863      14.435620      6.261590  16.113667
# 14  2020      8     17.072992      14.084097      6.016914   8.884980
# 15  2020      9     18.097972      15.011653      6.685333  15.810321
# 16  2020     10     41.493575      34.504462     16.499772  19.959514
# 17  2020     11    111.801027      84.965378     43.579686  11.958631
# 18  2020     12    140.218911      94.776008     44.139906  13.115591
# 19  2021      1    117.733293      62.581707     32.197272  15.029570
# 20  2021      2    116.575127      67.069538     41.331475  17.967213
# 21  2021      3    109.193737      65.657218     40.099194  22.823925
# 22  2021      4     58.667961      38.439581     24.473366  20.107542
# 23  2021      5     44.384425      31.015778     19.399892  24.317997
# 24  2021      6     33.194708      24.412472     14.699736   9.966620
# 25  2021      7     17.372245      12.573306      7.174005  10.258412
# 26  2021      8     19.781828      13.947298      8.517258   8.618280
# 27  2021      9     25.909181      18.283306     11.337361   9.505556
# 28  2021     10     41.760255      28.967016     16.975349  13.143817
# 29  2021     11     80.098931      56.717417     35.470667  11.412011
# 30  2021     12     94.828992      68.972392     44.074462  26.678763
# 31  2022      1    107.006183      76.221223     49.244624  25.892328
# 32  2022      2     86.151149      62.580776     40.027940  26.163690
# 33  2022      3     92.068911      65.403562     41.568293  16.875161
# 34  2022      4    110.171808      73.898707     47.585814   9.579625
# 35  2022      5    110.977379      73.641196     47.634382   9.193884
# 36  2022      6     42.301915      26.941740     17.416520   7.250073
#
#      CO (ppm)   NO (ppm)  NO2 (ppb)  Nox (ppb)   CO2 (ppm)       Hour  \
# 0         NaN        NaN        NaN        NaN         NaN  11.518459
# 1         NaN        NaN        NaN        NaN         NaN  11.500000
# 2         NaN        NaN        NaN        NaN         NaN  11.500000
# 3         NaN        NaN        NaN        NaN         NaN  11.500000
# 4         NaN        NaN        NaN        NaN         NaN  11.500000
# 5         NaN        NaN        NaN        NaN         NaN  11.500000
# 6    0.140000        NaN        NaN        NaN  328.600000  11.500000
# 7    0.397117   2.491529   5.994752   8.478306  333.652761  11.500000
# 8    1.009511   2.530797   6.004319   8.494025  373.174542  11.500000
# 9    0.829595   4.131712   8.471429  12.572951  383.324054  11.500000
# 10   0.764569   4.818554   8.881613  13.698331  419.564861  11.500000
# 11   0.742234   5.491250   9.238118  14.720417  415.148318  11.500000
# 12   0.609804   4.240811   8.303860  12.543357  393.372168  11.500000
# 13   0.613208   2.610687   5.694542   8.303760  393.411590  11.500000
# 14   0.622056   2.107039   4.720552   6.826097  393.622715  11.500000
# 15   0.634486   3.226653   6.765958   9.991181  408.194290  11.500000
# 16   0.710901   4.929530  10.550255  15.478427  413.151747  11.500000
# 17   0.931141   7.088231  12.374066  19.450942  418.858545  11.500000
# 18   0.905484   8.288199  11.913575  19.948898  445.961640  11.500000
# 19   1.095417   8.865685  13.247849  22.111720  427.362997  11.500000
# 20   0.843547  10.461967  12.238435  22.699046  433.013994  11.500000
# 21   1.035632   9.455941  11.940766  21.395524  430.169933  11.500000
# 22   0.870028   8.149693  12.241872  20.371131  424.581927  11.500000
# 23   0.750122   6.199296   9.143938  15.341894  416.791204  11.500000
# 24   0.855653   5.311056   7.752347  13.062181  414.625931  11.500000
# 25   0.905000   3.642675   5.971720   9.613468  415.000524  11.500000
# 26   0.900417   3.881680   6.446022  10.325927  415.034355  11.500000
# 27   0.904792   3.721264   5.956597   9.676347  415.159125  11.500000
# 28   0.908277   4.314745   6.746546  11.059731  415.107631  11.500000
# 29   0.954590   6.383444   9.268125  15.650319  415.408081  11.500000
# 30   1.020645   8.405067  12.470444  20.873831  415.323710  11.500000
# 31   1.016882   6.728293   9.910981  16.605645  415.265995  11.500000
# 32   0.924152   9.048423  13.317946  22.334985  399.417009  11.500000
# 33  10.740376  20.748844   5.902702  30.673145  410.288858  11.500000
# 34  14.772042  24.349444   0.983319  36.513213  410.752556  11.500000
# 35  14.074476  23.267191   1.018763  35.763441  413.297903  11.500000
# 36  11.777193  19.026053   1.020058  18.789474  413.062880  11.394737
#
#          Date
# 0  2019-06-01
# 1  2019-07-01
# 2  2019-08-01
# 3  2019-09-01
# 4  2019-10-01
# 5  2019-11-01
# 6  2019-12-01
# 7  2020-01-01
# 8  2020-02-01
# 9  2020-03-01
# 10 2020-04-01
# 11 2020-05-01
# 12 2020-06-01
# 13 2020-07-01
# 14 2020-08-01
# 15 2020-09-01
# 16 2020-10-01
# 17 2020-11-01
# 18 2020-12-01
# 19 2021-01-01
# 20 2021-02-01
# 21 2021-03-01
# 22 2021-04-01
# 23 2021-05-01
# 24 2021-06-01
# 25 2021-07-01
# 26 2021-08-01
# 27 2021-09-01
# 28 2021-10-01
# 29 2021-11-01
# 30 2021-12-01
# 31 2022-01-01
# 32 2022-02-01
# 33 2022-03-01
# 34 2022-04-01
# 35 2022-05-01
# 36 2022-06-01

# %% [markdown]
# #### Plot average pollutant levels by month and year

# %%
plt.figure(figsize=(24, 12))
for col in new_df.columns[1:-4]:  # Exclude non-pollutant columns
    plt.plot(monthly_mean['Date'], monthly_mean[col], label=col)
plt.title('Average Pollutant Levels by Month and Year')
plt.xlabel('Date')
plt.ylabel('Average Concentration')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# at the end of year and start of new year there are some more peak as compared other period

# %% [markdown]
# #### let's check it by season

# %%
def get_season(month):
    if month in [2,3]:
        return 'Spring'
    elif month in [4,5,6]:
        return 'Summer'
    elif month in [7,8,9,10]:
        return 'Autumn'
    else:
        return 'Winter'

new_df['Season'] = new_df['Date'].dt.month.apply(get_season)

# %%
new_df
# Out:
#                      Date  PM10 (ug/m3)  PM2.5 (ug/m3)  PM 1 (ug/m3)  \
# 0     2019-06-05 01:00:00         44.35          29.95         14.73
# 1     2019-06-05 02:00:00         42.13          28.35         13.93
# 2     2019-06-05 03:00:00         47.98          32.55         15.93
# 3     2019-06-05 04:00:00         58.43          39.73         19.33
# 4     2019-06-05 05:00:00         49.70          33.58         16.40
# ...                   ...           ...            ...           ...
# 26886 2022-06-29 07:00:00         12.68           6.80          4.38
# 26887 2022-06-29 08:00:00         13.43           7.30          4.70
# 26888 2022-06-29 09:00:00         21.65          12.85          8.33
# 26889 2022-06-29 10:00:00         15.58           8.75          5.65
# 26890 2022-06-29 11:00:00         13.70           7.50          4.85
#
#        O3 (ppb)  CO (ppm)  NO (ppm)  NO2 (ppb)  Nox (ppb)  CO2 (ppm)  Hour  \
# 0           NaN       NaN       NaN        NaN        NaN        NaN     1
# 1           NaN       NaN       NaN        NaN        NaN        NaN     2
# 2           NaN       NaN       NaN        NaN        NaN        NaN     3
# 3           NaN       NaN       NaN        NaN        NaN        NaN     4
# 4           NaN       NaN       NaN        NaN        NaN        NaN     5
# ...         ...       ...       ...        ...        ...        ...   ...
# 26886      6.33     10.57     16.90       1.04        3.0     415.14     7
# 26887      6.04     10.03     16.07       1.04        6.0     413.11     8
# 26888      6.78     11.40     18.19       0.95        9.0     419.65     9
# 26889      6.78     11.40     18.18       0.86       12.0     426.25    10
# 26890      6.71     11.20     17.92       0.99       15.0     421.09    11
#
#        DayOfWeek  Month  Year  Season
# 0      Wednesday      6  2019  Summer
# 1      Wednesday      6  2019  Summer
# 2      Wednesday      6  2019  Summer
# 3      Wednesday      6  2019  Summer
# 4      Wednesday      6  2019  Summer
# ...          ...    ...   ...     ...
# 26886  Wednesday      6  2022  Summer
# 26887  Wednesday      6  2022  Summer
# 26888  Wednesday      6  2022  Summer
# 26889  Wednesday      6  2022  Summer
# 26890  Wednesday      6  2022  Summer
#
# [26891 rows x 15 columns]

# %% [markdown]
# #### Plot boxplots of pollutants by season

# %%
plt.figure(figsize=(24, 16))
for i, col in enumerate(new_df.columns[1:-5]):  # Exclude non-pollutant columns
    plt.subplot(3, 3, i+1)
    sns.boxplot(x='Season', y=col, data=new_df)
    plt.title(col)
    plt.xlabel('Season')
    plt.ylabel('Concentration')
plt.tight_layout()
plt.show()

# %% [markdown]
# for most of the pollutants peak season is winter

# %% [markdown]
# #### Plot the trend of pollutant levels over different years

# %%
plt.figure(figsize=(24, 16))
for col in df.columns[2:11]:  # Exclude non-pollutant and 'Year' columns
    sns.lineplot(data=new_df, x=new_df['Year'], y=col, ci='sd', label=col)
plt.title('Trend of Pollutant Levels Over Different Years')
plt.xlabel('Year')
plt.ylabel('Pollutant Level')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Year by year intensity of pollutants increasing

# %% [markdown]
# ### This is Just EDA for practice. Environmnetalist, Climate Expertise can read intricacies of this dataset and suggest better solution.

# %% [markdown]
# Submitted By: Lavish Isasare
